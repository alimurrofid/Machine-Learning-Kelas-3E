# %% [markdown]
# # **Tugas 1**

# %% [markdown]
# **Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.**

# %% [markdown]
# ### **Step 1 - Load Library**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ### **Step 2 - Download CIFAR Dataset**

# %%
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# ### **Step 3 - Data Verification**

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
              'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
# One-Hot Encode Labels
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %% [markdown]
# #### **Step 4 - Create CNN Model**

# %% [markdown]
# #### **Step 4.1 - Create Convolution Layer**

# %%
# Model architecture
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))  # Adjusted dropout rate

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))  # Adjusted dropout rate

# %% [markdown]
# #### **Step 4.2 - Check Convolution Architecture**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  batch_normalization (Batch  (None, 30, 30, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 13, 13, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  batch_normalization_2 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
# =================================================================
# Total params: 94144 (367.75 KB)
# Trainable params: 93696 (366.00 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Step 4.3 - Add a Fully Connected Layer**

# %%
model.add(Flatten())

model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))  # Adjusted dropout rate

model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))  # Adjusted dropout rate

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #### **Step 4.4 - Check the CNN Model Architecture**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  batch_normalization (Batch  (None, 30, 30, 32)        128
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 13, 13, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 128)         73856
#
#  batch_normalization_2 (Bat  (None, 4, 4, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 2, 2, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 512)               262656
#
#  batch_normalization_3 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 493770 (1.88 MB)
# Trainable params: 491786 (1.88 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Step 4.5 - Compile CNN Model**

# %%
# Model compilation
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ### **Step 5 - Fit Model**

# %%
# Model training with one-hot encoded labels
history = model.fit(train_images, train_labels, epochs=100,  # Adjusted number of epochs
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/100
# 1563/1563 [==============================] - 29s 10ms/step - loss: 3.2231 - accuracy: 0.2618 - val_loss: 2.4779 - val_accuracy: 0.3990
# Epoch 2/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.6810 - accuracy: 0.3554 - val_loss: 2.3644 - val_accuracy: 0.4334
# Epoch 3/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.4482 - accuracy: 0.4056 - val_loss: 2.1757 - val_accuracy: 0.4819
# Epoch 4/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 2.2639 - accuracy: 0.4495 - val_loss: 2.0286 - val_accuracy: 0.5300
# Epoch 5/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.1134 - accuracy: 0.4874 - val_loss: 1.9270 - val_accuracy: 0.5494
# Epoch 6/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.9736 - accuracy: 0.5140 - val_loss: 1.7834 - val_accuracy: 0.5725
# Epoch 7/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.8496 - accuracy: 0.5410 - val_loss: 1.7566 - val_accuracy: 0.5703
# Epoch 8/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.7346 - accuracy: 0.5620 - val_loss: 1.6251 - val_accuracy: 0.5956
# Epoch 9/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.6324 - accuracy: 0.5813 - val_loss: 1.5086 - val_accuracy: 0.6129
# Epoch 10/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.5457 - accuracy: 0.5938 - val_loss: 1.3960 - val_accuracy: 0.6420
# Epoch 11/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.4638 - accuracy: 0.6096 - val_loss: 1.3348 - val_accuracy: 0.6433
# Epoch 12/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.3987 - accuracy: 0.6211 - val_loss: 1.2435 - val_accuracy: 0.6662
# Epoch 13/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 1.3250 - accuracy: 0.6372 - val_loss: 1.1907 - val_accuracy: 0.6748
# Epoch 14/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.2754 - accuracy: 0.6467 - val_loss: 1.1211 - val_accuracy: 0.6906
# Epoch 15/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.2293 - accuracy: 0.6536 - val_loss: 1.0991 - val_accuracy: 0.6911
# Epoch 16/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.1865 - accuracy: 0.6623 - val_loss: 1.1475 - val_accuracy: 0.6770
# Epoch 17/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.1510 - accuracy: 0.6668 - val_loss: 1.0437 - val_accuracy: 0.7049
# Epoch 18/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.1089 - accuracy: 0.6780 - val_loss: 0.9803 - val_accuracy: 0.7216
# Epoch 19/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 1.0790 - accuracy: 0.6838 - val_loss: 0.9714 - val_accuracy: 0.7207
# Epoch 20/100
# 1563/1563 [==============================] - 16s 10ms/step - loss: 1.0459 - accuracy: 0.6924 - val_loss: 0.9051 - val_accuracy: 0.7401
# Epoch 21/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0258 - accuracy: 0.6951 - val_loss: 0.9286 - val_accuracy: 0.7278
# Epoch 22/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 1.0026 - accuracy: 0.7008 - val_loss: 0.8849 - val_accuracy: 0.7400
# Epoch 23/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9788 - accuracy: 0.7078 - val_loss: 0.9378 - val_accuracy: 0.7197
# Epoch 24/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9690 - accuracy: 0.7081 - val_loss: 0.8668 - val_accuracy: 0.7434
# Epoch 25/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9445 - accuracy: 0.7161 - val_loss: 0.8885 - val_accuracy: 0.7369
# Epoch 26/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.9289 - accuracy: 0.7186 - val_loss: 0.8946 - val_accuracy: 0.7339
# Epoch 27/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.9138 - accuracy: 0.7221 - val_loss: 0.8949 - val_accuracy: 0.7342
# Epoch 28/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8991 - accuracy: 0.7271 - val_loss: 0.7878 - val_accuracy: 0.7673
# Epoch 29/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8856 - accuracy: 0.7291 - val_loss: 0.8101 - val_accuracy: 0.7540
# Epoch 30/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.8768 - accuracy: 0.7323 - val_loss: 0.7893 - val_accuracy: 0.7587
# Epoch 31/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.8595 - accuracy: 0.7392 - val_loss: 0.7755 - val_accuracy: 0.7656
# Epoch 32/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.8499 - accuracy: 0.7406 - val_loss: 0.7541 - val_accuracy: 0.7733
# Epoch 33/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8427 - accuracy: 0.7418 - val_loss: 0.7771 - val_accuracy: 0.7656
# Epoch 34/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8394 - accuracy: 0.7437 - val_loss: 0.7681 - val_accuracy: 0.7677
# Epoch 35/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8242 - accuracy: 0.7476 - val_loss: 0.7546 - val_accuracy: 0.7720
# Epoch 36/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8262 - accuracy: 0.7457 - val_loss: 0.7885 - val_accuracy: 0.7592
# Epoch 37/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8139 - accuracy: 0.7506 - val_loss: 0.7465 - val_accuracy: 0.7744
# Epoch 38/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7998 - accuracy: 0.7553 - val_loss: 0.7398 - val_accuracy: 0.7768
# Epoch 39/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.8039 - accuracy: 0.7512 - val_loss: 0.7047 - val_accuracy: 0.7886
# Epoch 40/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7925 - accuracy: 0.7570 - val_loss: 0.7423 - val_accuracy: 0.7770
# Epoch 41/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7871 - accuracy: 0.7590 - val_loss: 0.7390 - val_accuracy: 0.7759
# Epoch 42/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7801 - accuracy: 0.7609 - val_loss: 0.7287 - val_accuracy: 0.7815
# Epoch 43/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7723 - accuracy: 0.7636 - val_loss: 0.6880 - val_accuracy: 0.7953
# Epoch 44/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7694 - accuracy: 0.7640 - val_loss: 0.6986 - val_accuracy: 0.7896
# Epoch 45/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7641 - accuracy: 0.7671 - val_loss: 0.7015 - val_accuracy: 0.7890
# Epoch 46/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7610 - accuracy: 0.7668 - val_loss: 0.7119 - val_accuracy: 0.7883
# Epoch 47/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7582 - accuracy: 0.7673 - val_loss: 0.6950 - val_accuracy: 0.7931
# Epoch 48/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7543 - accuracy: 0.7694 - val_loss: 0.6783 - val_accuracy: 0.7984
# Epoch 49/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7505 - accuracy: 0.7692 - val_loss: 0.6815 - val_accuracy: 0.7948
# Epoch 50/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7476 - accuracy: 0.7710 - val_loss: 0.7322 - val_accuracy: 0.7800
# Epoch 51/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7411 - accuracy: 0.7745 - val_loss: 0.6821 - val_accuracy: 0.7961
# Epoch 52/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7316 - accuracy: 0.7771 - val_loss: 0.6917 - val_accuracy: 0.7931
# Epoch 53/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7374 - accuracy: 0.7742 - val_loss: 0.7288 - val_accuracy: 0.7788
# Epoch 54/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7349 - accuracy: 0.7760 - val_loss: 0.7190 - val_accuracy: 0.7845
# Epoch 55/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7295 - accuracy: 0.7789 - val_loss: 0.6989 - val_accuracy: 0.7894
# Epoch 56/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7291 - accuracy: 0.7787 - val_loss: 0.7371 - val_accuracy: 0.7765
# Epoch 57/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7254 - accuracy: 0.7789 - val_loss: 0.6606 - val_accuracy: 0.8039
# Epoch 58/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7203 - accuracy: 0.7838 - val_loss: 0.6595 - val_accuracy: 0.8087
# Epoch 59/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7198 - accuracy: 0.7808 - val_loss: 0.6672 - val_accuracy: 0.7990
# Epoch 60/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7155 - accuracy: 0.7820 - val_loss: 0.6615 - val_accuracy: 0.8030
# Epoch 61/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.7133 - accuracy: 0.7844 - val_loss: 0.6999 - val_accuracy: 0.7912
# Epoch 62/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7023 - accuracy: 0.7873 - val_loss: 0.6937 - val_accuracy: 0.7938
# Epoch 63/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6980 - accuracy: 0.7885 - val_loss: 0.6810 - val_accuracy: 0.8023
# Epoch 64/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7064 - accuracy: 0.7842 - val_loss: 0.6706 - val_accuracy: 0.8028
# Epoch 65/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.7056 - accuracy: 0.7865 - val_loss: 0.6764 - val_accuracy: 0.7991
# Epoch 66/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6958 - accuracy: 0.7921 - val_loss: 0.6714 - val_accuracy: 0.8032
# Epoch 67/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6996 - accuracy: 0.7896 - val_loss: 0.6901 - val_accuracy: 0.7979
# Epoch 68/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6966 - accuracy: 0.7894 - val_loss: 0.7012 - val_accuracy: 0.7926
# Epoch 69/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6973 - accuracy: 0.7921 - val_loss: 0.6596 - val_accuracy: 0.8058
# Epoch 70/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6883 - accuracy: 0.7928 - val_loss: 0.6925 - val_accuracy: 0.7956
# Epoch 71/100
# 1563/1563 [==============================] - 13s 9ms/step - loss: 0.6883 - accuracy: 0.7927 - val_loss: 0.6739 - val_accuracy: 0.8030
# Epoch 72/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6879 - accuracy: 0.7916 - val_loss: 0.6778 - val_accuracy: 0.7985
# Epoch 73/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6833 - accuracy: 0.7949 - val_loss: 0.6935 - val_accuracy: 0.7990
# Epoch 74/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6861 - accuracy: 0.7945 - val_loss: 0.6827 - val_accuracy: 0.7995
# Epoch 75/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6894 - accuracy: 0.7928 - val_loss: 0.6718 - val_accuracy: 0.8031
# Epoch 76/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6784 - accuracy: 0.7984 - val_loss: 0.6956 - val_accuracy: 0.7975
# Epoch 77/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6772 - accuracy: 0.7967 - val_loss: 0.6750 - val_accuracy: 0.8004
# Epoch 78/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6789 - accuracy: 0.7965 - val_loss: 0.6407 - val_accuracy: 0.8133
# Epoch 79/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6828 - accuracy: 0.7948 - val_loss: 0.6616 - val_accuracy: 0.8030
# Epoch 80/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6697 - accuracy: 0.8005 - val_loss: 0.6825 - val_accuracy: 0.7982
# Epoch 81/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6745 - accuracy: 0.7992 - val_loss: 0.6967 - val_accuracy: 0.7956
# Epoch 82/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6738 - accuracy: 0.7982 - val_loss: 0.6769 - val_accuracy: 0.8029
# Epoch 83/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6726 - accuracy: 0.8010 - val_loss: 0.6593 - val_accuracy: 0.8049
# Epoch 84/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6705 - accuracy: 0.7988 - val_loss: 0.6527 - val_accuracy: 0.8106
# Epoch 85/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6654 - accuracy: 0.7998 - val_loss: 0.6662 - val_accuracy: 0.8046
# Epoch 86/100
# 1563/1563 [==============================] - 15s 10ms/step - loss: 0.6638 - accuracy: 0.8038 - val_loss: 0.6407 - val_accuracy: 0.8118
# Epoch 87/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6571 - accuracy: 0.8051 - val_loss: 0.6477 - val_accuracy: 0.8087
# Epoch 88/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6620 - accuracy: 0.8041 - val_loss: 0.6996 - val_accuracy: 0.7923
# Epoch 89/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6671 - accuracy: 0.8036 - val_loss: 0.6611 - val_accuracy: 0.8085
# Epoch 90/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6580 - accuracy: 0.8040 - val_loss: 0.6696 - val_accuracy: 0.8033
# Epoch 91/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6590 - accuracy: 0.8037 - val_loss: 0.6548 - val_accuracy: 0.8106
# Epoch 92/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6526 - accuracy: 0.8057 - val_loss: 0.7429 - val_accuracy: 0.7866
# Epoch 93/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6547 - accuracy: 0.8047 - val_loss: 0.6549 - val_accuracy: 0.8105
# Epoch 94/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6570 - accuracy: 0.8057 - val_loss: 0.6419 - val_accuracy: 0.8138
# Epoch 95/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6524 - accuracy: 0.8068 - val_loss: 0.6497 - val_accuracy: 0.8114
# Epoch 96/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6513 - accuracy: 0.8081 - val_loss: 0.6650 - val_accuracy: 0.8025
# Epoch 97/100
# 1563/1563 [==============================] - 15s 9ms/step - loss: 0.6554 - accuracy: 0.8057 - val_loss: 0.6951 - val_accuracy: 0.8002
# Epoch 98/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6514 - accuracy: 0.8069 - val_loss: 0.7229 - val_accuracy: 0.7912
# Epoch 99/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6514 - accuracy: 0.8083 - val_loss: 0.6561 - val_accuracy: 0.8092
# Epoch 100/100
# 1563/1563 [==============================] - 14s 9ms/step - loss: 0.6509 - accuracy: 0.8064 - val_loss: 0.6362 - val_accuracy: 0.8167

# %% [markdown]
# ### **Step 6 - Model Evaluation**

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()

# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 1s - loss: 0.6362 - accuracy: 0.8167 - 1s/epoch - 4ms/step

# %% [markdown]
# ### **Step 7 - Print Accuracy Results**

# %%
print("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.8166999816894531

# %% [markdown]
# ## **Penjelasan**

# %% [markdown]
# Perbedaan utama antara kode pada Praktikum 2 dan setelah modifikasi adalah terletak pada beberapa aspek, terutama dalam arsitektur model dan parameter pelatihan. Berikut adalah perbedaan utama:
# 1. **Data Preprocessing:**
# - Sebelum: Menggunakan data langsung dari CIFAR-10 tanpa normalisasi atau one-hot encoding pada label.
# - Sesudah: Melakukan normalisasi data piksel antara 0 dan 1 dan menerapkan one-hot encoding pada label.
#
# 2. **Arsitektur Model:**
# - Sebelum: Terdiri dari lapisan konvolusi dan pooling tanpa dropout, dan hanya memiliki dua lapisan dense di akhir.
# - Sesudah: Menambahkan dropout pada beberapa lapisan konvolusi dan dense, serta menggunakan batch normalization untuk meningkatkan stabilitas pelatihan.
#
# 3. **Pelatihan Model:**
# - Sebelum: Melatih model selama 10 epoch.
# - Sesudah: Melatih model selama 100 epoch untuk memberikan model lebih banyak kesempatan untuk mempelajari pola pada data.
#
# 4. **Optimizer dan Learning Rate:**
# - Sebelum: Menggunakan optimizer Adam dengan learning rate default.
# - Sesudah: Menetapkan learning rate secara eksplisit pada 0.0001.
#
# 5. **Regularisasi:**
# - Sesudah: Menambahkan regularisasi L2 pada beberapa lapisan dense untuk mencegah overfitting.
#
# 6. **Penggunaan Dropout:**
# - Sebelum: Tidak menggunakan dropout pada model.
# - Sesudah: Menambahkan dropout pada beberapa lapisan konvolusi dan dense untuk mengurangi overfitting.
#
# Dengan menggabungkan semua perubahan ini, model yang dihasilkan dari kode sesudahnya diharapkan memiliki kemampuan yang lebih baik untuk mengatasi overfitting dan dapat mencapai akurasi 81% pada dataset pengujian CIFAR-10.

# %% [markdown]
# # **Tugas 2**

# %% [markdown]
# **Buatlah model CNN untuk klasifikasi dataset MNIST.**

# %% [markdown]
# ### **Step 1 - Load Library**

# %%
import numpy as np
from tensorflow.keras.datasets import mnist

# %% [markdown]
# ### **Step 2 - Load MNIST Dataset**

# %%
# Load MNIST dataset
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# ### **Step 3 - Data Verification**

# %%
# One-Hot Encode Labels
train_labels = to_categorical(train_labels, 10)
test_labels = to_categorical(test_labels, 10)

# %% [markdown]
# ### **Step 4 - Create CNN Model**

# %% [markdown]
# #### **Step 4.1 - Create Convolution Layer**

# %%
# Model architecture
model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))

# %% [markdown]
# #### **Step 4.2 - Check Convolution Layer**

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  batch_normalization_5 (Bat  (None, 26, 26, 32)        128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 13, 13, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        18496
#
#  batch_normalization_6 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         73856
#
#  batch_normalization_7 (Bat  (None, 3, 3, 128)         512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 128)         0
#
# =================================================================
# Total params: 93568 (365.50 KB)
# Trainable params: 93120 (363.75 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Step 4.3 - Add a Fully Connected Layer**

# %%
model.add(Flatten())

model.add(Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.4))

model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #### **Step 4.4 - Check the CNN Model Architecture**

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  batch_normalization_5 (Bat  (None, 26, 26, 32)        128
#  chNormalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 13, 13, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        18496
#
#  batch_normalization_6 (Bat  (None, 11, 11, 64)        256
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 5, 5, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 128)         73856
#
#  batch_normalization_7 (Bat  (None, 3, 3, 128)         512
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 1, 1, 128)         0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 1, 1, 128)         0
#
#  flatten_1 (Flatten)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 512)               66048
#
#  batch_normalization_8 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  batch_normalization_9 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 296586 (1.13 MB)
# Trainable params: 294602 (1.12 MB)
# Non-trainable params: 1984 (7.75 KB)
# _________________________________________________________________

# %% [markdown]
# #### **Step 4.5 - Compile CNN Model**

# %%
# Model compilation
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Reshape the images for compatibility with Conv2D layer
train_images = train_images.reshape((60000, 28, 28, 1))
test_images = test_images.reshape((10000, 28, 28, 1))

# %% [markdown]
# ### **Step 5 - Fit Model**

# %%
# Model training with one-hot encoded labels
history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 18s 8ms/step - loss: 1.6878 - accuracy: 0.6418 - val_loss: 0.7204 - val_accuracy: 0.9386
# Epoch 2/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.8965 - accuracy: 0.8781 - val_loss: 0.5984 - val_accuracy: 0.9637
# Epoch 3/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.7225 - accuracy: 0.9204 - val_loss: 0.5194 - val_accuracy: 0.9728
# Epoch 4/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.6019 - accuracy: 0.9410 - val_loss: 0.4464 - val_accuracy: 0.9795
# Epoch 5/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.5087 - accuracy: 0.9517 - val_loss: 0.3789 - val_accuracy: 0.9830
# Epoch 6/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.4304 - accuracy: 0.9575 - val_loss: 0.3237 - val_accuracy: 0.9845
# Epoch 7/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.3706 - accuracy: 0.9624 - val_loss: 0.2761 - val_accuracy: 0.9857
# Epoch 8/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.3219 - accuracy: 0.9658 - val_loss: 0.2365 - val_accuracy: 0.9864
# Epoch 9/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.2816 - accuracy: 0.9678 - val_loss: 0.2070 - val_accuracy: 0.9875
# Epoch 10/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2451 - accuracy: 0.9707 - val_loss: 0.1771 - val_accuracy: 0.9888
# Epoch 11/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.2171 - accuracy: 0.9725 - val_loss: 0.1563 - val_accuracy: 0.9887
# Epoch 12/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.1916 - accuracy: 0.9752 - val_loss: 0.1396 - val_accuracy: 0.9893
# Epoch 13/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1738 - accuracy: 0.9758 - val_loss: 0.1269 - val_accuracy: 0.9888
# Epoch 14/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1589 - accuracy: 0.9768 - val_loss: 0.1105 - val_accuracy: 0.9907
# Epoch 15/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1425 - accuracy: 0.9783 - val_loss: 0.1036 - val_accuracy: 0.9897
# Epoch 16/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1349 - accuracy: 0.9785 - val_loss: 0.0942 - val_accuracy: 0.9902
# Epoch 17/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1226 - accuracy: 0.9795 - val_loss: 0.0887 - val_accuracy: 0.9904
# Epoch 18/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1166 - accuracy: 0.9800 - val_loss: 0.0812 - val_accuracy: 0.9905
# Epoch 19/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1092 - accuracy: 0.9808 - val_loss: 0.0787 - val_accuracy: 0.9908
# Epoch 20/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 0.1031 - accuracy: 0.9815 - val_loss: 0.0720 - val_accuracy: 0.9908

# %% [markdown]
# ### **Step 6 - Model Evaluation**

# %%
# Plot training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### **Step 7 - Print Accuracy Results**

# %%
# Evaluate the model on the test set
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 - 2s - loss: 0.0720 - accuracy: 0.9908 - 2s/epoch - 5ms/step
# Test Accuracy: 0.9908000230789185

# %% [markdown]
# ### **Step 8 - Select Random Samples and Predict It**

# %%
# Select random samples from the test set
sample_indices = np.random.choice(test_images.shape[0], 15, replace=False)
sample_images = test_images[sample_indices]
sample_labels = test_labels[sample_indices]

# %%
# Make predictions on the samples
predictions = model.predict(sample_images)
# Out:
# 1/1 [==============================] - 0s 266ms/step

# %% [markdown]
# ### **Step 9 - Display Images and Its Predicted Labels**

# %%
# Display the images along with their true and predicted labels
plt.figure(figsize=(10, 5))
for i in range(15):
    plt.subplot(3, 5, i+1)
    plt.imshow(sample_images[i].reshape(28, 28), cmap='gray')
    plt.title(f'True: {np.argmax(sample_labels[i])}\nPredicted: {np.argmax(predictions[i])}')
    plt.axis('off')

plt.tight_layout(h_pad=1)
plt.show()

# %% [markdown]
# ## **Penjelasan**

# %% [markdown]
# Model Convolutional Neural Network (CNN) untuk klasifikasi gambar dataset MNIST telah berhasil dilatih yang mencapai tinggat akurasi 99%. Kesimpulan dari implementasi diatas adalah:
# 1. **Muat dan Praproses Data:**
# - Muat dataset MNIST, yang terdiri dari gambar berukuran 28x28 piksel dengan warna skala abu-abu dari digit tulisan tangan (0 hingga 9).
# - Normalisasi nilai piksel agar berada dalam rentang 0 hingga 1.
# - Lakukan one-hot encoding pada label.
#
# 2. **Arsitektur Model:**
# - Model CNN terdiri dari lapisan konvolusi untuk ekstraksi fitur, lapisan dropout untuk mengurangi overfitting, dan lapisan Dense untuk klasifikasi.
# - Batch normalization digunakan untuk mempercepat pelatihan dan mencegah overfitting.
#
# 3. **Pelatihan Model:**
# - Model dilatih selama 20 epoch dengan pengoptimal Adam dan fungsi kerugian categorical crossentropy.
# - Akurasi pada set validasi juga dipantau selama pelatihan untuk mengukur kinerja model.
#
# 4. **Evaluasi Model:**
# - Model mencapai akurasi yang baik pada set uji, menunjukkan kemampuannya untuk mengklasifikasikan digit MNIST.
#
# 5. **Visualisasi Hasil:**
# - Dilakukan visualisasi hasil prediksi pada 15 sampel acak dari set uji.
# - Tampilan gambar beserta label sebenarnya dan label yang diprediksi memberikan wawasan tentang kinerja model.
#
# Implementasi ini menunjukkan bahwa model CNN dapat berhasil diterapkan untuk tugas klasifikasi pada dataset gambar seperti MNIST dengan hasil tingkat akurasi yang tinggi.
