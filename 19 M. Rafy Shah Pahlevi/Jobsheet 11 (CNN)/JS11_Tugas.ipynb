# %% [markdown]
# # **Tugas**

# %% [markdown]
# -   Modifikasi model CNN pada praktikum 2 sehingga didapatkan akurasi testing lebih dari 80%.

# %% [markdown]
# # **Langkah 1: Impor pustaka dan modul yang diperlukan**

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
import pandas as pd
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, Dropout, MaxPooling2D, GlobalAveragePooling2D, Activation, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # **Langkah 2: Memuat dataset CIFAR-10**

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
print('Training set shape:', X_train.shape)
print('Test set shape:', X_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step
# Training set shape: (50000, 32, 32, 3)
# Test set shape: (10000, 32, 32, 3)

# %% [markdown]
# # **Langkah 3: Normalisasi data dan konversi label ke vektor one-hot encoded**

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# # **Langkah 4: Memisahkan data latih menjadi data latih dan data validasi**

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# # **Langkah 5: Mendefinisikan model Convolutional Neural Network (CNN)**

# %%
def cnn_model():
    model = Sequential()
    # First Conv layer
    model.add(Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4), input_shape=(32,32,3)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Second Conv layer
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Third, fourth, fifth convolution layer
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=512, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same', kernel_regularizer=regularizers.l2(1e-4)))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.3))

    # Fully Connected layers
    model.add(Flatten())

    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(10, activation='softmax'))

    model.summary()

    return model

# %% [markdown]
# # **Langkah 6: Membuat objek ImageDataGenerator dan mempersiapkan augmentasi data**

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=False
)
datagen.fit(X_train)

# %%
model = cnn_model()
model.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0003),
    metrics=['accuracy']
)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 128)       0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 256)       295168
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 512)         1180160
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 512)         2359808
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         1179904
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 256)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 7281802 (27.78 MB)
# Trainable params: 7281802 (27.78 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 8: Melatih model dengan ImageDataGenerator**

# %%
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=64),
    steps_per_epoch=len(X_train) // 64,
    epochs=125,
    validation_data=(X_valid, y_valid),
    verbose=1
)
# Out:
# Epoch 1/125
# 625/625 [==============================] - 48s 52ms/step - loss: 2.2165 - accuracy: 0.1672 - val_loss: 1.8429 - val_accuracy: 0.2929
# Epoch 2/125
# 625/625 [==============================] - 31s 50ms/step - loss: 1.8050 - accuracy: 0.3265 - val_loss: 1.5686 - val_accuracy: 0.4135
# Epoch 3/125
# 625/625 [==============================] - 31s 50ms/step - loss: 1.5935 - accuracy: 0.4216 - val_loss: 1.4105 - val_accuracy: 0.5009
# Epoch 4/125
# 625/625 [==============================] - 31s 50ms/step - loss: 1.4525 - accuracy: 0.4861 - val_loss: 1.2588 - val_accuracy: 0.5540
# Epoch 5/125
# 625/625 [==============================] - 31s 49ms/step - loss: 1.3570 - accuracy: 0.5308 - val_loss: 1.1650 - val_accuracy: 0.5889
# Epoch 6/125
# 625/625 [==============================] - 30s 49ms/step - loss: 1.2779 - accuracy: 0.5650 - val_loss: 1.0745 - val_accuracy: 0.6286
# Epoch 7/125
# 625/625 [==============================] - 31s 50ms/step - loss: 1.2118 - accuracy: 0.5896 - val_loss: 1.0418 - val_accuracy: 0.6350
# Epoch 8/125
# 625/625 [==============================] - 32s 51ms/step - loss: 1.1583 - accuracy: 0.6144 - val_loss: 1.0415 - val_accuracy: 0.6553
# Epoch 9/125
125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5381 - accuracy: 0.8811 - val_loss: 0.6449 - val_accuracy: 0.8505
# Epoch 111/125
# 625/625 [==============================] - 32s 50ms/step - loss: 0.5433 - accuracy: 0.8794 - val_loss: 0.6650 - val_accuracy: 0.8464
# Epoch 112/125
# 625/625 [==============================] - 31s 49ms/step - loss: 0.5416 - accuracy: 0.8813 - val_loss: 0.6571 - val_accuracy: 0.8469
# Epoch 113/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5476 - accuracy: 0.8788 - val_loss: 0.6047 - val_accuracy: 0.8663
# Epoch 114/125
# 625/625 [==============================] - 32s 50ms/step - loss: 0.5356 - accuracy: 0.8820 - val_loss: 0.6464 - val_accuracy: 0.8509
# Epoch 115/125
# 625/625 [==============================] - 31s 49ms/step - loss: 0.5372 - accuracy: 0.8810 - val_loss: 0.6784 - val_accuracy: 0.8452
# Epoch 116/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5420 - accuracy: 0.8814 - val_loss: 0.6990 - val_accuracy: 0.8365
# Epoch 117/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5386 - accuracy: 0.8811 - val_loss: 0.6488 - val_accuracy: 0.8527
# Epoch 118/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5357 - accuracy: 0.8831 - val_loss: 0.5832 - val_accuracy: 0.8735
# Epoch 119/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5385 - accuracy: 0.8808 - val_loss: 0.6076 - val_accuracy: 0.8629
# Epoch 120/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5284 - accuracy: 0.8842 - val_loss: 0.6484 - val_accuracy: 0.8520
# Epoch 121/125
# 625/625 [==============================] - 30s 49ms/step - loss: 0.5322 - accuracy: 0.8849 - val_loss: 0.6439 - val_accuracy: 0.8551
# Epoch 122/125
# 625/625 [==============================] - 31s 49ms/step - loss: 0.5346 - accuracy: 0.8838 - val_loss: 0.6424 - val_accuracy: 0.8523
# Epoch 123/125
# 625/625 [==============================] - 31s 49ms/step - loss: 0.5385 - accuracy: 0.8843 - val_loss: 0.6383 - val_accuracy: 0.8536
# Epoch 124/125
# 625/625 [==============================] - 32s 51ms/step - loss: 0.5365 - accuracy: 0.8845 - val_loss: 0.5951 - val_accuracy: 0.8685
# Epoch 125/125
# 625/625 [==============================] - 31s 50ms/step - loss: 0.5322 - accuracy: 0.8860 - val_loss: 0.6328 - val_accuracy: 0.8603

# %% [markdown]
# # **Langkah 9: Mengevaluasi model pada set tes**

# %%
scores = model.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6352 - accuracy: 0.8607

# %% [markdown]
# # **Langkah 10: Melakukan prediksi**

# %%
pd.DataFrame(history.history).plot()
# Out:
# <Axes: >

# %% [markdown]
# # **Langkah 11: Tampilkan laporan klasifikasi**

# %%
scores = model.evaluate(X_test, y_test)
pred = model.predict(X_test)
labels = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(y_test, axis=1)
errors = y_pred - y_true != 0
print(classification_report(y_true, y_pred))
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6352 - accuracy: 0.8607
# 313/313 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.87      1000
#            1       0.91      0.96      0.94      1000
#            2       0.92      0.73      0.82      1000
#            3       0.81      0.68      0.74      1000
#            4       0.82      0.88      0.85      1000
#            5       0.86      0.74      0.80      1000
#            6       0.86      0.93      0.89      1000
#            7       0.79      0.94      0.86      1000
#            8       0.89      0.95      0.92      1000
#            9       0.90      0.90      0.90      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %% [markdown]
# # **Langkah 12: Menampilkan visualisasi hasil prediksi**

# %%
fig, axes = plt.subplots(5, 5, figsize=(12,12))
axes = axes.ravel()
for i in np.arange(25):
    axes[i].imshow(X_test[i])
    axes[i].set_title('True: %s \nPredict: %s' % (labels[y_true[i]], labels[y_pred[i]]))
    axes[i].axis('off')
    plt.subplots_adjust(wspace=1)

# %% [markdown]
# -  Buatlah model CNN untuk klasifikasi dataset MNIST.

# %% [markdown]
# # **Langkah 1: Memuat Dataset MNIST**

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist

# Memuat dataset MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # **Langkah 2: Normalisasi Gambar ke Rentang [0, 1]**

# %%
# Normalisasi gambar ke rentang [0, 1]
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# # **Langkah 3: Mengonversi Label ke Format One-Hot Encoding**

# %%
# Perbaikan: Mengimpor to_categorical dari tensorflow.keras.utils
from tensorflow.keras.utils import to_categorical

# Mengonversi label ke format one-hot encoding
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# %% [markdown]
# # **Langkah 4: Menampilkan Informasi tentang Dataset**

# %%
# Menampilkan informasi tentang dataset
print("Jumlah data latihan:", len(train_images))
print("Jumlah data pengujian:", len(test_images))
print("Ukuran gambar:", train_images[0].shape)
# Out:
# Jumlah data latihan: 60000
# Jumlah data pengujian: 10000
# Ukuran gambar: (28, 28)

# %% [markdown]
# # **Langkah 5: Membangun Model**

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Membangun model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28,28,1)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # **Langkah 6: Mengompilasi Model**

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # **Langkah 7: Menampilkan Ringkasan Model**

# %%
# Menampilkan ringkasan model
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPoolin  (None, 13, 13, 32)        0
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 5, 5, 64)          0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 128)               204928
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_6 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 232650 (908.79 KB)
# Trainable params: 232650 (908.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # **Langkah 8: Melatih Model**

# %%
# Melatih model
history = model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=2, validation_split=0.3)
# Out:
# Epoch 1/10
# 329/329 - 4s - loss: 0.3881 - accuracy: 0.8795 - val_loss: 0.0887 - val_accuracy: 0.9735 - 4s/epoch - 12ms/step
# Epoch 2/10
# 329/329 - 2s - loss: 0.1012 - accuracy: 0.9701 - val_loss: 0.0607 - val_accuracy: 0.9819 - 2s/epoch - 6ms/step
# Epoch 3/10
# 329/329 - 2s - loss: 0.0687 - accuracy: 0.9799 - val_loss: 0.0472 - val_accuracy: 0.9862 - 2s/epoch - 5ms/step
# Epoch 4/10
# 329/329 - 2s - loss: 0.0541 - accuracy: 0.9841 - val_loss: 0.0493 - val_accuracy: 0.9847 - 2s/epoch - 5ms/step
# Epoch 5/10
# 329/329 - 2s - loss: 0.0460 - accuracy: 0.9863 - val_loss: 0.0478 - val_accuracy: 0.9858 - 2s/epoch - 6ms/step
# Epoch 6/10
# 329/329 - 2s - loss: 0.0392 - accuracy: 0.9882 - val_loss: 0.0398 - val_accuracy: 0.9887 - 2s/epoch - 6ms/step
# Epoch 7/10
# 329/329 - 2s - loss: 0.0329 - accuracy: 0.9896 - val_loss: 0.0410 - val_accuracy: 0.9886 - 2s/epoch - 6ms/step
# Epoch 8/10
# 329/329 - 2s - loss: 0.0291 - accuracy: 0.9911 - val_loss: 0.0386 - val_accuracy: 0.9899 - 2s/epoch - 5ms/step
# Epoch 9/10
# 329/329 - 2s - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.0368 - val_accuracy: 0.9903 - 2s/epoch - 6ms/step
# Epoch 10/10
# 329/329 - 2s - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.0431 - val_accuracy: 0.9889 - 2s/epoch - 5ms/step

# %% [markdown]
# # **Langkah 9: Plot Sejarah Pelatihan**

# %%
import matplotlib.pyplot as plt

# Plot sejarah pelatihan
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Akurasi Pelatihan')
plt.plot(history.history['val_accuracy'], label='Akurasi Validasi')
plt.legend(loc='lower right')
plt.title('Akurasi Pelatihan dan Validasi')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Loss Pelatihan')
plt.plot(history.history['val_loss'], label='Loss Validasi')
plt.legend(loc='upper right')
plt.title('Loss Pelatihan dan Validasi')
# Out:
# Text(0.5, 1.0, 'Loss Pelatihan dan Validasi')

# %% [markdown]
# # **Langkah 10: Evaluasi Model pada Kumpulan Data Uji**

# %%
# Evaluasi model pada kumpulan data uji
validation_loss, validation_accuracy = model.evaluate(test_images, test_labels, verbose=False)
print("Loss Validasi:", validation_loss)
print("Akurasi Validasi:", validation_accuracy)
# Out:
# Loss Validasi: 0.033910248428583145
# Akurasi Validasi: 0.9902999997138977

# %% [markdown]
# # **Langkah 11: Menghasilkan Nilai Prediksi pada Kumpulan Data Uji**

# %%
# Menghasilkan nilai prediksi pada kumpulan data uji
y_pred_enc = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# # **Langkah 12: Mendekode Nilai Prediksi**

# %%
# Mendekode nilai prediksi
y_pred = [np.argmax(i) for i in y_pred_enc]

# %% [markdown]
# # **Langkah 13: Menampilkan Laporan Klasifikasi**

# %%
# Menampilkan laporan klasifikasi
print(classification_report(np.argmax(test_labels, axis=1), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       980
#            1       0.99      1.00      1.00      1135
#            2       0.99      0.99      0.99      1032
#            3       1.00      0.99      0.99      1010
#            4       0.99      1.00      0.99       982
#            5       0.99      0.99      0.99       892
#            6       1.00      0.98      0.99       958
#            7       0.98      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.98      0.99      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %% [markdown]
# # **Langkah 14: Membuat Matriks Konfusi dan Menampilkannya dengan Heatmap**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Membuat matriks konfusi dan menampilkannya dengan heatmap
fig, ax = plt.subplots(figsize=(7, 7))
sns.heatmap(confusion_matrix(np.argmax(test_labels, axis=1), y_pred), annot=True, cbar=False, fmt='1d', cmap='Blues', ax=ax)
ax.set_title('Matriks Konfusi', loc='left', fontsize=16)
ax.set_xlabel('Prediksi')
ax.set_ylabel('Aktual')
# Out:
# Text(58.222222222222214, 0.5, 'Aktual')

# %% [markdown]
# # **Langkah 15: Menampilkan Target yang Diprediksi pada Setiap Gambar (Label di atas gambar adalah label yang diprediksi)**

# %%
# Menampilkan target yang diprediksi pada setiap gambar
# (label di atas gambar adalah label yang diprediksi)
plt.figure(figsize=(18, 12))
for ind, row in enumerate(test_images[:15]):
    plt.subplot(3, 5, ind+1)
    plt.title(y_pred[ind])
    img = row.reshape(28, 28)
    plt.axis('off')
    plt.imshow(img, cmap='cividis')
