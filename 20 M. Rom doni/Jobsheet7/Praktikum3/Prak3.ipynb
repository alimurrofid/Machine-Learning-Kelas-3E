# %% [markdown]
# kode program dibawh Melakukan Instalasi Minisom

# %%
from minisom import MiniSom
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# kode program dibawah Melakukan Loading Dataset

# %%
# Load dataset
iris = datasets.load_iris()
data = iris.data

# %% [markdown]
# kode program dibawah di gunakan untuk Normalisasi Data

# %%
# Normalisasi data
data = data / data.max(axis=0)

# %% [markdown]
# kode program dibawah Melakukan Inisialisasi SOM (Self-Optimizing Maps)

# %%
# Inisialisasi SOM
map_size = (10, 10)
som = MiniSom(map_size[0], map_size[1], data.shape[1], sigma=0.5, learning_rate=0.5)

# %% [markdown]
# kode program dibawah Melakukan Inisialiasi Bobot Secara Random

# %%
# Inisialisasi bobot secara acak
som.random_weights_init(data)

# %% [markdown]
# kode program dibawah Melakukan Pelatihan Data

# %%
# Pelatihan SOM
num_epochs = 100
som.train_random(data, num_epochs)

# %% [markdown]
# kode program dibawah untuk visualisasi data

# %%
# Visualisasi hasil SOM
plt.figure(figsize=(8, 8))
for i, x in enumerate(data):
    w = som.winner(x)  # Pemenang untuk sampel x
    plt.text(w[0]+.5, w[1]+.5, str(i+1), color='k', fontdict={'weight': 'bold', 'size': 11})
plt.pcolor(som.distance_map().T, cmap='bone_r', alpha=.2)
plt.colorbar()

plt.show()
